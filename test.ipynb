# %%
print("hieu")
# Out:
# hieu

# %%
n=int(input())
sum=0
for i in range(1, n+1):
    sum += i
print(sum)
# Out:
# 364

# %%
n=int(input())
m=0
while n <= 0:
    n=int(input())
for i in range (2, n):
    if n%i==0:
        m = 1
if m==0 and n != 1:
    print("snt")
else:
    print("0")
# Out:
# 0

# %%
n=int(input())
gt=1
for i in range (1,n+1):
    gt *= i
print(gt)
# Out:
# 6227020800

# %%
n=int(input())
m=0
n = abs(n)
if n == 0:
    m=1
while n >0:
    n=n // 10
    m+=1
print(m)
# Out:
# 3

# %%
n=int(input())
m=0
while n<=0:
    n=int(input())
for i in range(n):
    n=int(input())
    if n==42:
        m=1
if m==0:
    print('o')
else:
    print("luck")
# Out:
# luck

# %%
def checkprime(n):
    for i in range (2,n):
        if n%i==0:
            return False
    return n>1
checkprime(2)
# Out:
# True

# %%
def checkprime(n):
    for i in range (2,n):
        if n%i==0:
            return False
    return n>1
n=int(input())
for i in range (n,0,-1 ):
    if n%i==0 and checkprime(i):
        print(i)
        break
# Out:
# 3

# %%
n=int(input())
m=0
while str(n) != str(n)[::-1]:
    n = n + int(str(n)[::-1])
    m+=1
print(m, n)
# Out:
# 4 4884

# %%
n=int(input())
i=1
u=[]
while i*i <= n:
    s=str(i*i)
    i+=1
    if len(s) == len(set(s)):
        u.append(s)
if u:
    print(*u)
else:
    print("l")
# Out:
# 1

# %%
def col(n):
    m=1
    while n != 1:
        if n%2==0:
            n=n/2
        else:
            n=3*n+1
        m+=1
    return m
n=int(input())
maxlen=0
so=0
for i in range(1, n+1):
    l=col(i)
    if l>maxlen:
        maxlen=l
        so=i
print(so, maxlen)
# Out:
# 9 20

# %%
n=int(input())
m=0
assert n<10**6 and n>0, "nhap lai diiii"
for i in range(2,n+1):
    if n%i==0 and i%2==0:
        m+=1
print(m)
# Out:
# 3

# %%
X, n=map(int, input().split())
X= X*1.007**n
print(int(X))
# Out:
# 1

# %%
a,b=map(int, input().split())
tong1,tong2=0,0
for i in range(1,a):
    if a%i==0:
        tong1 += i
for j in range(1,b):
    if b%j==0:
        tong2 += j
if tong1==b and tong2==a:
    print("co")
else:
    print("no")
# Out:
# no

# %%
m, n= map(int, input().split())
u=[]
for i in range(1,m+1):
    if m%i==0 and n%i==0:
        u.append(i)
print(max(u))
# Out:
# 2

# %%
a,b=map(int,input().split())
y=b/2-a
x=a-y
if y==int(y):
    print(int(x), int(y))
else:
    print("invalid")
# Out:
# 22.0 14.0

# %%
for i in range(3,101,3):
    if i%2==0:
        print(i, end=" ")
# Out:
# 6 12 18 24 30 36 42 48 54 60 66 72 78 84 90 96

# %%
for j in range(2,11):
    print(f"bảng cửu chương {j} là:")
    for i in range(1,11):
        print(j, "x",i,"=",j*i)
# Out:
# bảng cửu chương 2 là:
# 2 x 1 = 2
# 2 x 2 = 4
# 2 x 3 = 6
# 2 x 4 = 8
# 2 x 5 = 10
# 2 x 6 = 12
# 2 x 7 = 14
# 2 x 8 = 16
# 2 x 9 = 18
# 2 x 10 = 20
# bảng cửu chương 3 là:
# 3 x 1 = 3
# 3 x 2 = 6
# 3 x 3 = 9
# 3 x 4 = 12
# 3 x 5 = 15
# 3 x 6 = 18
# 3 x 7 = 21
# 3 x 8 = 24
# 3 x 9 = 27
# 3 x 10 = 30
# bảng cửu chương 4 là:
# 4 x 1 = 4
# 4 x 2 = 8
# 4 x 3 = 12
# 4 x 4 = 16
# 4 x 5 = 20
# 4 x 6 = 24
# 4 x 7 = 28
# 4 x 8 = 32
# 4 x 9 = 36
# 4 x 10 = 40
# bảng cửu chương 5 là:
# 5 x 1 = 5
# 5 x 2 = 10
# 5 x 3 = 15
# 5 x 4 = 20
# 5 x 5 = 25
# 5 x 6 = 30
# 5 x 7 = 35
# 5 x 8 = 40
# 5 x 9 = 45
# 5 x 10 = 50
# bảng cửu chương 6 là:
# 6 x 1 = 6
# 6 x 2 = 12
# 6 x 3 = 18
# 6 x 4 = 24
# 6 x 5 = 30
# 6 x 6 = 36
# 6 x 7 = 42
# 6 x 8 = 48
# 6 x 9 = 54
# 6 x 10 = 60
# bảng cửu chương 7 là:
# 7 x 1 = 7
# 7 x 2 = 14
# 7 x 3 = 21
# 7 x 4 = 28
# 7 x 5 = 35
# 7 x 6 = 42
# 7 x 7 = 49
# 7 x 8 = 56
# 7 x 9 = 63
# 7 x 10 = 70
# bảng cửu chương 8 là:
# 8 x 1 = 8
# 8 x 2 = 16
# 8 x 3 = 24
# 8 x 4 = 32
# 8 x 5 = 40
# 8 x 6 = 48
# 8 x 7 = 56
# 8 x 8 = 64
# 8 x 9 = 72
# 8 x 10 = 80
# bảng cửu chương 9 là:
# 9 x 1 = 9
# 9 x 2 = 18
# 9 x 3 = 27
# 9 x 4 = 36
# 9 x 5 = 45
# 9 x 6 = 54
# 9 x 7 = 63
# 9 x 8 = 72
# 9 x 9 = 81
# 9 x 10 = 90
# bảng cửu chương 10 là:
# 10 x 1 = 10
# 10 x 2 = 20
# 10 x 3 = 30
# 10 x 4 = 40
# 10 x 5 = 50
# 10 x 6 = 60
# 10 x 7 = 70
# 10 x 8 = 80
# 10 x 9 = 90
# 10 x 10 = 100

# %%
a,b=map(int, input().split())
for i in range(1,a+1):
    if a%i==0 and b%i==0:
        print(i, end=" ")
# Out:
# 1 2 4 5 8 10 20 40

# %%
n=int(input())
for i in range(2,n+1,2):
    print(i, end=" ")
# Out:
# 2 4 6 8

# %%
n=int(input())
while n%2==0:
        n = n//2
if n==1:
    print("có")
else:
    print("0")
# Out:
# 0

# %%
n=input()
sum=0
for i in n:
    sum += int(i)
print(sum)
# Out:
# 21

# %%
n=input()
c=0
l=0
for i in n:
    if int(i)%2==0:
        c+=1 
    else:
        l+=1
print(c,l)
# Out:
# 3 1

# %%
n=int(input())
s=0
k=0
while s<n:
    k+=1
    s+=k
print(k-1)
# Out:
# 4

# %%
A=int(input())
s=0
k=0
while s<A:
    k+=1
    s= s+1/k
print(k)
# Out:
# 4

# %%
u=[]
while True:
    n=int(input())
    if n!=-1:
        u.append(n)
    else:
        break
print(max(u), min(u))
# Out:
# 10 -4

# %%
f1,f2=1,1
A=int(input())
while f2<A:
    f1,f2=f2,f1+f2
print(f1)
# Out:
# 8

# %%
n=input().strip()
cach=1
for i in n:
    if i==" ":
        cach+=1
print(cach)
# Out:
# 3

# %%
A=input()
u=""
for i in A:
    if i != " ":
        u += i
    else:
        break
print(u)
# Out:
# 123

# %%
n=input()
hoa=0
thuong=0
so=0
for i in n:
    if i.isdigit():
        so+=1
    elif i.isupper():
        hoa+=1
    else:
        thuong+=1
print(hoa,thuong,so)
# Out:
# 2 3 4

# %%
n=int(input())
s=str(n)[::-1]
kq=s[0:3]
for i in range (3,len(s),3):
    kq=kq + "." + s[i:i+3]
print(kq[::-1])
# Out:
# 12.345.678

# %%
a=input()
b=input()
kq=""
i=0
while i < len(a):
    if a[i:i+len(b)]==b:
        i+=len(b)
    else:
        kq+=a[i]
        i+=1
print(kq)
# Out:
# hu hu

# %%
# a=438
# b=636
# print("a + b = ", a+b)
# print("a - b = ", a-b)
# print("a * b = ", a*b)
# print("a / b = ", a/b)
a = 438
b = 636
print("a + b = " + str(a + b))
print("a - b = " + str(a - b))
print("a * b = " + str(a * b))
print("a / b = " + str(a / b))
# Out:
# a + b = 1074
# a - b = -198
# a * b = 278568
# a / b = 0.6886792452830188

# %%
def input(a,b):
    i=a%b
    print(f"{a}%{b} = {i}")
input(7,3)
# Out:
# 7%3 = 1

# %%
i=2
tich=1
while tich<=50:
    tich*=i
    i+=2
print(tich)
# Out:
# 384

# %%
from random import randint
computer=randint(0,2)
me=input("nhap keo or bua or bao")
if computer==0:
    computer="keo"
if computer==1:
    compouter="bua"
if computer==2:
    computer="bao"
print("computer ra", computer)
print("ban ra", me)
if me=="keo":
    if computer=="keo":
        print("draw")
    elif computer=="bao":
        print("win")
    else:
        print("lose")
if me=="bua":
    if computer=="keo":
        print("win")
    elif computer=="bao":
        print("lose")
    else:
        print("lose")
if me=="bao":
    if computer=="keo":
        print("lose")
    elif computer=="bao":
        print("draw")
    else:
        print("win")
# Out:
# computer ra bao
# ban ra bua
# lose

# %%
def namnhuan(n):
    if n%400==0 or n%4==0 and n%100!=0:
        return True
    return False
a,b,c=map(int, input().split())
sum=0
for i in range(1,b):
    if i in(1,3,5,7,8,10,12):
        sum+=31
    elif i==2:
        if namnhuan(c):
            sum+=29
        else:
            sum+=28
    else:
        sum+=30
print(sum+a)
# Out:
# 365

# %%
def fibo(n):
    if n<=2:
        return 1
    return fibo(n-1)+fibo(n-2)
A=int(input())
a=1
while fibo(a)<=A:
        a+=1
print(fibo(a-1))
# Out:
# 8

# %%
def dem(n):
    m=0
    while n>1:
        n=n//10
        m+=1
    return dem
dem(n=int(input()))
# Out:
#   Cell In[3], line 1
#     def fib(n):
#                ^
# _IncompleteInputError: incomplete input

# %%
def dem(n):
    m=0
    while n>1:
        n=n//10
        m+=1
    return dem
dem(n=int(input()))
